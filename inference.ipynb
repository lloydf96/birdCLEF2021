# %% [markdown]
# ### Inference
# Here we use the trained model to find the labels for soundscapes at every 5 second interval.

# %%
import os
import pandas as pd
from audionet import *
from audio_dataset import *
from train import *

# %%
label_to_idx = {'banana': 0,
 'tromoc': 1,
 'buggna': 2,
 'haiwoo': 3,
 'rudtur': 4,
 'thbkin': 5,
 'wooduc': 6,
 'gbwwre1': 7,
 'rewbla': 8,
 'spotow': 9,
 'naswar': 10,
 'chbchi': 11,
 'yebsap': 12,
 'yehcar1': 13,
 'purfin': 14,
 'brratt1': 15,
 'houfin': 16,
 'swathr': 17,
 'hutvir': 18,
 'leafly': 19,
 'grethr1': 20,
 'rucwar1': 21,
 'herwar': 22,
 'roahaw': 23,
 'subfly': 24,
 'mouwar': 25,
 'mallar3': 26,
 'azaspi1': 27,
 'pabspi1': 28,
 'butsal1': 29,
 'wegspa1': 30,
 'wewpew': 31,
 'marwre': 32,
 'yebcha': 33,
 'yerwar': 34,
 'scrtan1': 35,
 'lesvio1': 36,
 'prowar': 37,
 'rutjac1': 38,
 'putfru1': 39,
 'btnwar': 40,
 'whtdov': 41,
 'whcpar': 42,
 'sonspa': 43,
 'banswa': 44,
 'rucspa1': 45,
 'towsol': 46,
 'grcfly': 47,
 'stbori': 48,
 'annhum': 49,
 'buhvir': 50,
 'bcnher': 51,
 'trogna1': 52,
 'blctan1': 53,
 'comrav': 54,
 'daejun': 55,
 'laufal1': 56,
 'bewwre': 57,
 'whcspa': 58,
 'rthhum': 59,
 'astfly': 60,
 'bawswa1': 61,
 'eursta': 62,
 'magwar': 63,
 'chispa': 64,
 'grhowl': 65,
 'soulap1': 66,
 'ribgul': 67,
 'mastro1': 68,
 'foxspa': 69,
 'grtgra': 70,
 'btbwar': 71,
 'houwre': 72,
 'bawwar': 73,
 'pasfly': 74,
 'mouchi': 75,
 'norpar': 76,
 'brbsol1': 77,
 'gilwoo': 78,
 'eastow': 79,
 'ruboro1': 80,
 'blugrb1': 81,
 'purgal2': 82,
 'cangoo': 83,
 'wesblu': 84,
 'coltro1': 85,
 'amered': 86,
 'osprey': 87,
 'rufhum': 88,
 'reevir1': 89,
 'yelgro': 90,
 'lesgre1': 91,
 'gcrwar': 92,
 'sibtan2': 93,
 'sposan': 94,
 'brebla': 95,
 'killde': 96,
 'cacwre': 97,
 'treswa': 98,
 'amerob': 99,
 'pinsis': 100,
 'lobgna5': 101,
 'rtlhum': 102,
 'rocpig': 103,
 'scptyr1': 104,
 'crfpar': 105,
 'acowoo': 106,
 'norcar': 107,
 'whtspa': 108,
 'dowwoo': 109,
 'squcuc1': 110,
 'grycat': 111,
 'yebori1': 112,
 'whwbec1': 113,
 'sinwre1': 114,
 'plsvir': 115,
 'grnher': 116,
 'chbant1': 117,
 'larspa': 118,
 'creoro1': 119,
 'rawwre1': 120,
 'baleag': 121,
 'carwre': 122,
 'brnthr': 123,
 'tropar': 124,
 'meapar': 125,
 'tenwar': 126,
 'gnwtea': 127,
 'orcpar': 128,
 'whevir': 129,
 'tuftit': 130,
 'bkbplo': 131,
 'rubpep1': 132,
 'caltow': 133,
 'comloo': 134,
 'cubthr': 135,
 'hofwoo1': 136,
 'bncfly': 137,
 'sumtan': 138,
 'blujay': 139,
 'bobfly1': 140,
 'cobtan1': 141,
 'weskin': 142,
 'rehbar1': 143,
 'grekis': 144,
 'chswar': 145,
 'rinkin1': 300,
 'thswar1': 301,
 'ocbfly1': 302,
 'bongul': 303,
 'socfly1': 304,
 'amekes': 305,
 'dusfly': 306,
 'cowscj1': 307,
 'westan': 308,
 'rugdov': 309,
 'swaspa': 310,
 'blhpar1': 311,
 'easmea': 312,
 'oliwoo1': 313,
 'laugul': 314,
 'gbbgul': 315,
 'orcwar': 316,
 'stejay': 317,
 'savspa': 318,
 'grnjay': 319,
 'cocwoo1': 320,
 'royter1': 321,
 'yetvir': 322,
 'incdov': 323,
 'amewig': 324,
 'rotbec': 325,
 'nutwoo': 326,
 'woothr': 327,
 'colcha1': 328,
 'rumfly1': 329,
 'rubwre1': 330,
 'shicow': 331,
 'monoro1': 332,
 'thbeup1': 333,
 'plaxen1': 334,
 'greegr': 335,
 'phivir': 336,
 'banwre1': 337,
 'yehbla': 338,
 'relpar': 339,
 'pygnut': 340,
 'greyel': 341,
 'gartro1': 342,
 'rebsap': 343,
 'compot1': 344,
 'wbwwre1': 345,
 'sthant1': 346,
 'comgol': 347,
 'amegfi': 348,
 'macwar': 349,
 'wrenti': 350,
 'brwhaw': 351,
 'chcant2': 352,
 'coohaw': 353,
 'brwpar1': 354,
 'heptan': 355,
 'cotfly1': 356,
 'yegvir': 357,
 'gocspa': 358,
 'labwoo': 359,
 'wiltur': 360,
 'bushti': 361,
 'whfpar1': 362,
 'amepip': 363,
 'tropew1': 364,
 'cedwax': 365,
 'stvhum2': 366,
 'chbwre1': 367,
 'gretin1': 368,
 'tunswa': 369,
 'barant1': 370,
 'strsal1': 371,
 'goowoo1': 372,
 'flrtan1': 373,
 'whimbr': 374,
 'casfin': 375,
 'mouqua': 376,
 'nrwswa': 377,
 'sthwoo1': 378,
 'saypho': 379,
 'bucmot2': 380,
 'y00475': 381,
 'gamqua': 382,
 'calqua': 383,
 'rudpig': 384,
 'yefgra1': 385,
 'blsspa1': 386,
 'olsfly': 387,
 'commer': 388,
 'canwar': 389,
 'vigswa': 390,
 'fiespa': 391,
 'cogdov': 392,
 'easpho': 393,
 'yebfly': 394,
 'sander': 395,
 'leasan': 396,
 'nocall': 397}

# %%
# This is where we will store our results
pred = {'row_id': [], 'birds': []}
idx_to_label = idx_to_label
test_audio = list_files(os.path.join(os.getcwd(),'test_soundscapes'))
# Analyze each soundscape recording
for path in test_audio:
    
    # Open file with Librosa
    y,sr = librosa.load(path,sr = 32000)
    # Split file into 5-second chunks
    y_len = len(y)
    
    k=0
    fileinfo = path.split(os.sep)[-1].rsplit('.', 1)[0].split('_')
    label_list = []
    for second in range(5, y_len, 5):
        
        s_start = int(max(0,(second - 5) * 32000))
        s_end =int( min(second * 32000,y_len))
        y_in = y[s_start:s_end]
        if len(y_in) != 32000*5:
            continue
            
        y_in_sig = sig_to_mel(torch.unsqueeze(torch.tensor(y_in),dim = 0)).to(device)

        y_op=sig(model_5(y_in_sig).detach())

        idx = torch.argmax(y_op)
        label = idx_to_label[idx.item()]
        
        row_id = fileinfo[0] + '_'  + fileinfo[1] + '_'  + str(second)  
        pred['row_id'].append(row_id)
        
        pred['birds'].append(label)

        
# Make a new data frame and look at a few "results"
results = pd.DataFrame(pred, columns = ['row_id', 'birds'])

# %%
# Convert our results to csv
results.to_csv("submission.csv", index=False)

# %% [markdown]
# Reference:
#
# https://www.kaggle.com/stefankahl/birdclef2021-sample-submission
